# %%
import matplotlib.pyplot as plt

# %%
# year and population inputs
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972]

# %%
# Using matplotlib to plot the 2 variables
plt.plot(year, pop)

# %%
# change the plot function to scatter
plt.scatter(year, pop)

# %%
plt.show()
